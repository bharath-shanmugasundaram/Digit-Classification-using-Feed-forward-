# %%
import numpy as np
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
def hot_value(n):
    return np.array([1 if i==n else 0 for i in range(0,10)])

# %%
Y=np.array([hot_value(i) for i in y_train])
YT=np.array([hot_value(i) for i in y_test])
X = np.array([i.flatten() for i in X_train]) / 255.0
XT = np.array([i.flatten() for i in X_test]) / 255.0
print(X[0].shape)
# Out:
# (784,)

# %%
def softmax(z):
    exp=np.exp(z-np.max(z,axis=1,keepdims=True))
    return exp/np.sum(exp,axis=1,keepdims=True)

def cross_ent(y_true,y_pred):
    m = y_true.shape[0]
    return -np.sum(y_true * np.log(y_pred + 1e-9)) / m

def relu(z):
    return np.maximum(0, np.minimum(z, 1e6))  # clip extreme values

def relu_derivative(z):
    return (z > 0).astype(float)

# %%
np.random.seed(42)
W1 = np.random.randn(784, 10) * np.sqrt(2.0/784)
W2 = np.random.randn(10, 4)   * np.sqrt(2.0/10)
W3 = np.random.randn(4, 10)   * np.sqrt(2.0/4)

b1=np.zeros((1,10))
b2=np.zeros((1,4))
b3=np.zeros((1,10))

lr=0.1
epochs=10000

# %%
def forward(X, W1, b1, W2, b2, W3, b3):
    Z1 = X @ W1 + b1
    A1 = relu(Z1)

    Z2 = A1 @ W2 + b2
    A2 = relu(Z2)

    Z3 = A2 @ W3 + b3
    A3 = softmax(Z3)

    cache = (Z1, A1, Z2, A2, Z3, A3)
    return A3, cache

# %%
def backward(X, y, cache, W1, W2, W3):
    Z1, A1, Z2, A2, Z3, A3 = cache
    m = X.shape[0]

    dZ3 = A3 - y
    dW3 = A2.T @ dZ3 / m
    db3 = np.sum(dZ3, axis=0, keepdims=True) / m

    dA2 = dZ3 @ W3.T
    dZ2 = dA2 * relu_derivative(Z2)
    dW2 = A1.T @ dZ2 / m
    db2 = np.sum(dZ2, axis=0, keepdims=True) / m

    dA1 = dZ2 @ W2.T
    dZ1 = dA1 * relu_derivative(Z1)
    dW1 = X.T @ dZ1 / m
    db1 = np.sum(dZ1, axis=0, keepdims=True) / m

    return dW1, db1, dW2, db2, dW3, db3

# %%
for epoch in range(epochs):
    y_pred, cache = forward(X, W1, b1, W2, b2, W3, b3)

    loss = cross_ent(Y, y_pred)

    dW1, db1, dW2, db2, dW3, db3 = backward(X, Y, cache, W1, W2, W3)

    W1 -= lr * dW1; b1 -= lr * db1
    W2 -= lr * dW2; b2 -= lr * db2
    W3 -= lr * dW3; b3 -= lr * db3

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.4f}")
# Out:
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: divide by zero encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: overflow encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: invalid value encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: divide by zero encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: overflow encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: invalid value encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: divide by zero encountered in matmul
#   Z3 = A2 @ W3 + b3
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: overflow encountered in matmul
#   Z3 = A2 @ W3 + b3
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: invalid value encountered in matmul
#   Z3 = A2 @ W3 + b3
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:6: RuntimeWarning: divide by zero encountered in matmul
#   dW3 = A2.T @ dZ3 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:6: RuntimeWarning: overflow encountered in matmul
#   dW3 = A2.T @ dZ3 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:6: RuntimeWarning: invalid value encountered in matmul
#   dW3 = A2.T @ dZ3 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:9: RuntimeWarning: divide by zero encountered in matmul
#   dA2 = dZ3 @ W3.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:9: RuntimeWarning: overflow encountered in matmul
#   dA2 = dZ3 @ W3.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:9: RuntimeWarning: invalid value encountered in matmul
#   dA2 = dZ3 @ W3.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:11: RuntimeWarning: divide by zero encountered in matmul
#   dW2 = A1.T @ dZ2 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:11: RuntimeWarning: overflow encountered in matmul
#   dW2 = A1.T @ dZ2 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:11: RuntimeWarning: invalid value encountered in matmul
#   dW2 = A1.T @ dZ2 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:14: RuntimeWarning: divide by zero encountered in matmul
#   dA1 = dZ2 @ W2.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:14: RuntimeWarning: overflow encountered in matmul
#   dA1 = dZ2 @ W2.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:14: RuntimeWarning: invalid value encountered in matmul
#   dA1 = dZ2 @ W2.T
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:16: RuntimeWarning: divide by zero encountered in matmul
#   dW1 = X.T @ dZ1 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:16: RuntimeWarning: overflow encountered in matmul
#   dW1 = X.T @ dZ1 / m
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/3883023311.py:16: RuntimeWarning: invalid value encountered in matmul
#   dW1 = X.T @ dZ1 / m
# Epoch 0, Loss: 2.4085
# Epoch 100, Loss: 1.4177
# Epoch 200, Loss: 1.0429
# Epoch 300, Loss: 0.8812
# Epoch 400, Loss: 0.7500
# Epoch 500, Loss: 0.6587
# Epoch 600, Loss: 0.5972
# Epoch 700, Loss: 0.5540
# Epoch 800, Loss: 0.5222
# Epoch 900, Loss: 0.4966
# Epoch 1000, Loss: 0.4743
# Epoch 1100, Loss: 0.4546
# Epoch 1200, Loss: 0.4362
# Epoch 1300, Loss: 0.4180
# Epoch 1400, Loss: 0.4027
# Epoch 1500, Loss: 0.3903
# Epoch 1600, Loss: 0.3799
# Epoch 1700, Loss: 0.3710
# Epoch 1800, Loss: 0.3633
# Epoch 1900, Loss: 0.3565
# Epoch 2000, Loss: 0.3505
# Epoch 2100, Loss: 0.3450
# Epoch 2200, Loss: 0.3401
# Epoch 2300, Loss: 0.3355
# Epoch 2400, Loss: 0.3313
# Epoch 2500, Loss: 0.3273
# Epoch 2600, Loss: 0.3235
# Epoch 2700, Loss: 0.3200
# Epoch 2800, Loss: 0.3167
# Epoch 2900, Loss: 0.3135
# Epoch 3000, Loss: 0.3105
# Epoch 3100, Loss: 0.3077
# Epoch 3200, Loss: 0.3050
# Epoch 3300, Loss: 0.3024
# Epoch 3400, Loss: 0.2999
# Epoch 3500, Loss: 0.2976
# Epoch 3600, Loss: 0.2955
# Epoch 3700, Loss: 0.2934
# Epoch 3800, Loss: 0.2915
# Epoch 3900, Loss: 0.2896
# Epoch 4000, Loss: 0.2879
# Epoch 4100, Loss: 0.2862
# Epoch 4200, Loss: 0.2846
# Epoch 4300, Loss: 0.2830
# Epoch 4400, Loss: 0.2815
# Epoch 4500, Loss: 0.2800
# Epoch 4600, Loss: 0.2786
# Epoch 4700, Loss: 0.2773
# Epoch 4800, Loss: 0.2760
# Epoch 4900, Loss: 0.2747
# Epoch 5000, Loss: 0.2735
# Epoch 5100, Loss: 0.2724
# Epoch 5200, Loss: 0.2712
# Epoch 5300, Loss: 0.2701
# Epoch 5400, Loss: 0.2690
# Epoch 5500, Loss: 0.2680
# Epoch 5600, Loss: 0.2670
# Epoch 5700, Loss: 0.2660
# Epoch 5800, Loss: 0.2650
# Epoch 5900, Loss: 0.2641
# Epoch 6000, Loss: 0.2631
# Epoch 6100, Loss: 0.2622
# Epoch 6200, Loss: 0.2613
# Epoch 6300, Loss: 0.2605
# Epoch 6400, Loss: 0.2596
# Epoch 6500, Loss: 0.2589
# Epoch 6600, Loss: 0.2580
# Epoch 6700, Loss: 0.2573
# Epoch 6800, Loss: 0.2564
# Epoch 6900, Loss: 0.2557
# Epoch 7000, Loss: 0.2550
# Epoch 7100, Loss: 0.2544
# Epoch 7200, Loss: 0.2538
# Epoch 7300, Loss: 0.2529
# Epoch 7400, Loss: 0.2524
# Epoch 7500, Loss: 0.2519
# Epoch 7600, Loss: 0.2512
# Epoch 7700, Loss: 0.2498
# Epoch 7800, Loss: 0.2494
# Epoch 7900, Loss: 0.2488
# Epoch 8000, Loss: 0.2494
# Epoch 8100, Loss: 0.2481
# Epoch 8200, Loss: 0.2464
# Epoch 8300, Loss: 0.2472
# Epoch 8400, Loss: 0.2476
# Epoch 8500, Loss: 0.2445
# Epoch 8600, Loss: 0.2449
# Epoch 8700, Loss: 0.2450
# Epoch 8800, Loss: 0.2425
# Epoch 8900, Loss: 0.2425
# Epoch 9000, Loss: 0.2457
# Epoch 9100, Loss: 0.2405
# Epoch 9200, Loss: 0.2422
# Epoch 9300, Loss: 0.2436
# Epoch 9400, Loss: 0.2387
# Epoch 9500, Loss: 0.2390
# Epoch 9600, Loss: 0.2429
# Epoch 9700, Loss: 0.2422
# Epoch 9800, Loss: 0.2371
# Epoch 9900, Loss: 0.2383

# %%
def accuracy(y_true, y_pred):
    pred_labels = np.argmax(y_pred, axis=1)
    true_labels = np.argmax(y_true, axis=1)
    return np.mean(pred_labels == true_labels)

# %%
y_test_pred, _ = forward(XT, W1, b1, W2, b2, W3, b3)
test_acc = accuracy(YT, y_test_pred)
print("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.9174
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: divide by zero encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: overflow encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:2: RuntimeWarning: invalid value encountered in matmul
#   Z1 = X @ W1 + b1
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: divide by zero encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: overflow encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:5: RuntimeWarning: invalid value encountered in matmul
#   Z2 = A1 @ W2 + b2
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: divide by zero encountered in matmul
#   Z3 = A2 @ W3 + b3
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: overflow encountered in matmul
#   Z3 = A2 @ W3 + b3
# /var/folders/zm/gf8ny5z13m70t3shtcspf3rh0000gp/T/ipykernel_95504/1043581783.py:8: RuntimeWarning: invalid value encountered in matmul
#   Z3 = A2 @ W3 + b3

# %%
np.save("W1.npy", W1)
np.save("b1.npy", b1)
np.save("W2.npy", W2)
np.save("b2.npy", b2)
np.save("W3.npy", W3)
np.save("b3.npy", b3)
